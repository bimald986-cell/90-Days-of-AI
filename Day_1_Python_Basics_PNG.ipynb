# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/Day_1_Python_Basics_PNG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World! I am building AI in 90 days.")
# Out:
# Hello World! I am building AI in 90 days.

# %%
# Variables store information for us
total_days = 90
days_completed = 5

# Python can do math automatically
days_remaining = total_days - days_completed

# Display the result
print("Goal:", total_days, "days")
print("Days remaining:", days_remaining)
# Out:
# Goal: 90 days
# Days remaining: 85
