# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/Learn_with_Kaggle_PNG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = "Bimal"
print (Name)
# Out:
# Bimal

# %%
Name = "Bimal"
Bimal = "Me"
if Bimal == "Me":
    print (Name)
# Out:
# Bimal

# %%
Hello = "You are a good person"
print(Hello)
print("You've successfully run some Python code")
print("Congratulations!")
# Out:
# You are a good person
# You've successfully run some Python code
# Congratulations!
