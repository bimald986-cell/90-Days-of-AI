# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
topics = ["AI", "Consciousness", "Time", "Mystery"]
print(topics)
# Out:
# ['AI', 'Consciousness', 'Time', 'Mystery']

# %%
print(topics[0])
# Out:
# AI

# %%
print(topics[1])
print(topics[2])
print(topics[3])
# Out:
# Consciousness
# Time
# Mystery

# %%
topics.append("Robotics")
print(topics)
# Out:
# ['AI', 'Consciousness', 'Time', 'Mystery', 'Robotics']

# %%
print(len(topics))
# Out:
# 5

# %%
topics.append("Spirituality")

# %%
print(topics)
print(len(topics))
# Out:
# ['AI', 'Consciousness', 'Time', 'Mystery', 'Robotics', 'Spirituality']
# 6

# %%
for topic in topics:
  print(topic)
# Out:
# AI
# Consciousness
# Time
# Mystery
# Robotics
# Spirituality

# %%
for topic in topics:
  print("Mind & Mythos topic:", topic)
# Out:
# Mind & Mythos topic: AI
# Mind & Mythos topic: Consciousness
# Mind & Mythos topic: Time
# Mind & Mythos topic: Mystery
# Mind & Mythos topic: Robotics
# Mind & Mythos topic: Spirituality

# %%
ideas[]
# Out:
#   File "/tmp/ipykernel_920/1938823178.py", line 1
#     ideas[]
#           ^
# SyntaxError: invalid syntax

# %%
ideas = []

# %%
idea1 = input("Is time real?: ")
idea2 = input("Can AI become conscious?: ")
idea3 = input("Why do humans fear death?: ")
# Out:
# Is time real?: yes
# Can AI become conscious?: maybe
# Why do humans fear death?: not sure

# %%
ideas.append(idea1)
ideas.append(idea2)
ideas.append(idea3)

# %%
print("\nIs time real?:\n")
for idea in ideas:
  print("-", idea)
  print("\nTotal ideas:", len(ideas))
# Out:
# Is time real?:
#
# - yes
#
# Total ideas: 5
# - yes
#
# Total ideas: 5
# - yes
#
# Total ideas: 5
# - maybe
#
# Total ideas: 5
# - not sure
#
# Total ideas: 5

# %%
ideas = []
num_ideas = int(input("How many ideas do you want to create?"))
for i in range(num_ideas):
  idea = input(f"Enter idea {i+1}: ")
  ideas.append(idea)
  print("\nIs time real?:\n")
  for idea in ideas:
    print("-", idea)
    print("\nTotal ideas:", len(ideas))
# Out:
# How many ideas do you want to create?10
# Enter idea 1: My
#
# Is time real?:
#
# - My
#
# Total ideas: 1
# Enter idea 2: Name
#
# Is time real?:
#
# - My
#
# Total ideas: 2
# - Name
#
# Total ideas: 2
# Enter idea 3: Is
#
# Is time real?:
#
# - My
#
# Total ideas: 3
# - Name
#
# Total ideas: 3
# - Is
#
# Total ideas: 3
# Enter idea 4: Bimal
#
# Is time real?:
#
# - My
#
# Total ideas: 4
# - Name
#
# Total ideas: 4
# - Is
#
# Total ideas: 4
# - Bimal
#
# Total ideas: 4
# Enter idea 5: Dahal
#
# Is time real?:
#
# - My
#
# Total ideas: 5
# - Name
#
# Total ideas: 5
# - Is
#
# Total ideas: 5
# - Bimal
#
# Total ideas: 5
# - Dahal
#
# Total ideas: 5
# Enter idea 6: I am
#
# Is time real?:
#
# - My
#
# Total ideas: 6
# - Name
#
# Total ideas: 6
# - Is
#
# Total ideas: 6
# - Bimal
#
# Total ideas: 6
# - Dahal
#
# Total ideas: 6
# - I am
#
# Total ideas: 6
# Enter idea 7: Running
#
# Is time real?:
#
# - My
#
# Total ideas: 7
# - Name
#
# Total ideas: 7
# - Is
#
# Total ideas: 7
# - Bimal
# ...
