# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/Day_03_Decision_Maker%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
  plan = "Deep learning session"
elif learning_hours >= 1:
  plan = "Standard learning session"
elif learning_hours == 0:
  plan = "Quick learning session"
else:
  plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? bimal
# How old are you? 34
# How many hours can you study today? .05
#
# Hello bimal
# Age: 34
# Today's plan: Rest today, but come back tomorrow.

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? bimal
# How old are you? 34
# How many hours can you study today? 2
#
# Hello bimal
# Age: 34
# Today's plan: Deep learning session

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? Bimal
# How old are you? 34
# How many hours can you study today? 1
#
# Hello Bimal
# Age: 34
# Today's plan: Standard learning session

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? Bimal Dahal
# How old are you? 34 years
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3856/1636800341.py in <cell line: 0>()
#       1 name = input("What is your name? ")
# ----> 2 age = int(input("How old are you? "))
#       3 learning_hours = float(input("How many hours can you study today? "))
#       4
#       5 if learning_hours >= 2:
#
# ValueError: invalid literal for int() with base 10: '34 years'

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? Bimal Dahal
# How old are you? 34
# How many hours can you study today? .05
#
# Hello Bimal Dahal
# Age: 34
# Today's plan: Quick learning session

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? Bimal D
# How old are you? 34.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3856/1636800341.py in <cell line: 0>()
#       1 name = input("What is your name? ")
# ----> 2 age = int(input("How old are you? "))
#       3 learning_hours = float(input("How many hours can you study today? "))
#       4
#       5 if learning_hours >= 2:
#
# ValueError: invalid literal for int() with base 10: '34.5'

# %%
name = input("What is your name? ")
age = int(input("How old are you? "))
learning_hours = float(input("How many hours can you study today? "))

if learning_hours >= 2:
    plan = "Deep learning session"
elif learning_hours >= 1:
    plan = "Standard learning session"
elif learning_hours > 0:   # more than 0 but less than 1
    plan = "Quick learning session"
else:   # exactly 0
    plan = "Rest today, but come back tomorrow."

print("\nHello", name)
print("Age:", age)
print("Today's plan:", plan)
# Out:
# What is your name? Bimal D
# How old are you? 34
# How many hours can you study today? 0
#
# Hello Bimal D
# Age: 34
# Today's plan: Rest today, but come back tomorrow.
