# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = {
    "name": "Bimal",
    "course": "AI",
    "day": 5
}
print(student)
# Out:
# {'name': 'Bimal', 'course': 'AI', 'day': 5}

# %%
print(student["name"])
print(student["course"])
print(student["day"])
# Out:
# Bimal
# AI
# 5

# %%
student["day"] = 6
student["goal"] = "Build AI applications"

print(student)
# Out:
# {'name': 'Bimal', 'course': 'AI', 'day': 6, 'goal': 'Build AI applications'}

# %%
for key, value in student.items():
  print(key, ":", value)
# Out:
# name : Bimal
# course : AI
# day : 6
# goal : Build AI applications

# %%
# Day 5 - My AI Journey Dictionary
my_ai_journey = {
    "day": 5
    "focus": "Paython Dictionaries",
    "goal": "Build AI applications",
    "project": "Astrolab learning system"
}

print("My AI Journey:\n")
for key, value in my_ai_jpurney.items():
  print(key, ":", value)
# Out:
#   File "/tmp/ipykernel_544/3797664380.py", line 3
#     "day": 5
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Day 5 - My AI Journey Dictionary
my_ai_journey = {
    "day": 5
    "focus": "Python Dictionaries",
    "goal": "Build AI applications",
    "project": "Astrolab learning system"
}

print("My AI Journey:\n")
for key, value in my_ai_journey.items():
  print(key, ":", value)
# Out:
#   File "/tmp/ipykernel_544/721889849.py", line 3
#     "day": 5
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Day 5 - My AI Journey Dictionary
my_ai_journey = {
    "day": 5,
    "focus": "Python Dictionaries",
    "goal": "Build AI applications",
    "project": "Astrolab learning system"
}

print("My AI Journey:\n")
for key, value in my_ai_journey.items():
  print(key, ":", value)
# Out:
# My AI Journey:
#
# day : 5
# focus : Python Dictionaries
# goal : Build AI applications
# project : Astrolab learning system
