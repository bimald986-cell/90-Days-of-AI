# %% [markdown]
# <a href="https://colab.research.google.com/github/bimald986-cell/90-Days-of-AI/blob/main/learning_status_day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
  print("Hello", name)

greet("Bimal")
# Out:
# Hello Bimal

# %%
def learning_status(name, day):
  print(name, "is currently on day", day, "of AI leraning.")

learning_status("Bimal", 6)
# Out:
# Bimal is currently on day 6 of AI leraning.

# %%
def learning_status(name, day):
  print(name, "is currently on day", day, "of AI leraning.")

learning_status("Mike", 2)
# Out:
# Mike is currently on day 2 of AI leraning.

# %%
def marrige_status(name, status, number):
  print(name, "is currently", status, "for", number, "years.")

marrige_status("Ram", "married", 2)
# Out:
# Ram is currently married for 2 years.
